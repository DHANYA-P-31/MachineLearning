# %%
import pandas as pd

df = pd.read_csv("input_data.csv")
texts = df["Text"].tolist()
print(df)
print(texts)
# Out:
#    ID                   Text Sentiment
# 0   1    I love this product  Positive
# 1   2    Very bad experience  Negative
# 2   3        Amazing quality  Positive
# 3   4    Not worth the money  Negative
# 4   5  Excellent performance  Positive
# 5   6       Terrible support  Negative
# 6   7    Happy with purchase  Positive
# 7   8          Waste of time  Negative
# 8   9             Good value  Positive
# 9  10           Disappointed  Negative
# ['I love this product', 'Very bad experience', 'Amazing quality', 'Not worth the money', 'Excellent performance', 'Terrible support', 'Happy with purchase', 'Waste of time', 'Good value', 'Disappointed']

# %%
from transformers import pipeline

classifier = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)
# Out:
# Device set to use cpu

# %%
results = classifier(texts)

for text, result in zip(texts, results):
    print(f"Text: {text}")
    print(f"Prediction: {result['label']} (Score: {result['score']:.2f})\n")

test_text= "not good"
result = classifier(test_text)
print(test_text, result)
# Out:
# Text: I love this product
# Prediction: POSITIVE (Score: 1.00)
#
# Text: Very bad experience
# Prediction: NEGATIVE (Score: 1.00)
#
# Text: Amazing quality
# Prediction: POSITIVE (Score: 1.00)
#
# Text: Not worth the money
# Prediction: NEGATIVE (Score: 1.00)
#
# Text: Excellent performance
# Prediction: POSITIVE (Score: 1.00)
#
# Text: Terrible support
# Prediction: NEGATIVE (Score: 0.62)
#
# Text: Happy with purchase
# Prediction: POSITIVE (Score: 1.00)
#
# Text: Waste of time
# Prediction: NEGATIVE (Score: 1.00)
#
# Text: Good value
# Prediction: POSITIVE (Score: 1.00)
#
# Text: Disappointed
# Prediction: NEGATIVE (Score: 1.00)
#
# not good [{'label': 'NEGATIVE', 'score': 0.9997889399528503}]
